# %%
import pyswarms as ps
import psopy
import math
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

# %%
# Import modules
import numpy as np

# Import sphere function as objective function

# Import backend modules
import pyswarms.backend as P
from pyswarms.backend.topology import Star

import pyswarms as ps
from pyswarms.utils.functions import single_obj as fx
from pyswarms.utils.plotters import plot_cost_history, plot_contour, plot_surface
import matplotlib.pyplot as plt
from pyswarms.utils.plotters.formatters import Mesher, Designer

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 22])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Datframe

# %%
df = pd.read_csv('data/icr-nliq-computer-science.csv')
df = df.fillna(0)
df['ICR'] = df['ICR'].replace(0,0.01)
df
# Out:
#                                    Institute  Articles  Articles w/ IC  \
# 0                            Yale University       139              38
# 1                           Brown University       113              32
# 2                          Boston University       135              37
# 3                    University of Groningen       108              31
# 4              Humboldt University of Berlin       113              29
# ..                                       ...       ...             ...
# 70                     University of Baghdad         8               2
# 71  Hanoi University of Science & Technology        15              10
# 72                 University of Puerto Rico        16              10
# 73                         Atilim University        31               6
# 74                      Universite de Bejaia        12               6
#
#     Total Citations  Parent Country Citations       ICR      NLIQ   Ranking
# 0              2698                      1122  0.447413  0.584136         8
# 1              2381                      1027  0.487884  0.568669        53
# 2              4170                      1740  0.490636  0.582734        61
# 3              1901                       308  0.490845  0.837980        73
# 4              2930                       697  0.590844  0.762116        74
# ..              ...                       ...       ...       ...       ...
# 70              341                        15  0.473333  0.956012  801-1000
# 71              160                         8  0.683347  0.950000  801-1000
# 72              668                       161  0.441312  0.758982  801-1000
# 73              416                        85  0.638889  0.795673  801-1000
# 74              121                         0  0.428241  1.000000  801-1000
#
# [75 rows x 8 columns]

# %% [markdown]
# # CES function

# %%
class Q:
    def setparams(self,alpha=0.5,eta=1,K=0.306173,L=0.388889):
        self.K = K
        self.L = L
        self.alpha = alpha
        self.eta = eta
        
    def Q(self,rho):
        q1 = (self.alpha * self.K**rho) + (1 - self.alpha)*(self.L**rho)
        q = q1 ** (self.eta/rho)
        return q

    def Q1(self,rho):
        q = self.Q(rho)
        if (self.K**self.alpha)*(self.L**(1-self.alpha)) == 0:
            return 0
        q1_1 = q ** (-rho/self.eta) * math.log( (self.K**self.alpha)*(self.L**(1-self.alpha)) )
        if q == 0:
            return 0
        q1 = q1_1 / math.log(q)
        return q1
    
    def Q1_new(self,rho):
        r = (self.alpha * self.K**rho) + (1 - self.alpha)*(self.L**rho)
        q1 = self.K**(self.alpha*self.K**rho) * self.L**((1-self.alpha)*self.L**rho)
        res = ( (self.Q(rho)*self.eta) / (r*rho) ) * math.log(q1/(r**(r/rho)))
        return res
        
q =Q()
q.setparams(K=0.3061728395, L=0.38888888899999996,alpha=0.5)
def f(x):
    l,r = x.shape
    F = []
    for i in range(l):
        temp = []
        for j in range(r):
            #t = x[i][j]*math.sin(math.pi*x[i][j]*10)+1.0
            t = q.Q(x[i][j]) 
            #temp.append(t)
        F.append(t)
    #print(F)
    return np.array(F)

# %%
q.Q(0.10114881)
# Out:
# 0.34531076902733304

# %% [markdown]
# # PSO optimization using inbuilt pySwarm

# %%
print(q.K,q.L)
q.setparams(K=df['ICR'][0],L=df['NLIQ'][0],alpha=0.5)
max_bound = 1.0 * np.ones(1)
min_bound = 0.0 * np.ones(1)
bounds = (min_bound, max_bound)
# Set-up optimizer
options = {'c1': 0.6, 'c2': 0.3, 'w': 0.9}
optimizer = ps.single.GlobalBestPSO(n_particles=25, dimensions=1, options=options, bounds=bounds)
optimizer.optimize(f, iters=100)
# Plot the cost
plot_cost_history(optimizer.cost_history)
plt.savefig('cost.png')
plt.show()
# Out:
# 2020-05-28 02:52:06,921 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6, 'c2': 0.3, 'w': 0.9}
#
#
# pyswarms.single.global_best:   0%|          |0/100
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
# 0.4474134631 0.5841363973
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  49%|████▉     |49/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best:  91%|█████████ |91/100, best_cost=0.511
#
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=0.511[A
# 2020-05-28 02:52:07,156 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.511225887583767, best pos: [0.00030559]

# %%
from IPython.display import HTML
# %matplotlib inline
import matplotlib.animation# Plot the sphere function's mesh for better plots
m = Mesher(func=f,
           #limits=[(-1,1), (-1,1)]
          )
# Adjust figure limits
d = Designer(
    #limits=[(-1,1), (-1,1), (-0.1,1)],
             label=['x-axis', 'y-axis', 'z-axis'])

pos_history_3d = m.compute_history_3d(optimizer.pos_history) # preprocessing
animation3d = plot_surface(pos_history=pos_history_3d,
                           mesher=m, designer=d,
                           mark=(0,0,0))   
plt.savefig('cost3D.png')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.animation
import numpy as np

t = np.linspace(0,2*np.pi)
x = np.sin(t)

fig, ax = plt.subplots()
l, = ax.plot([0,2*np.pi],[-1,1])

animate = lambda i: l.set_data(t[:i], x[:i])

ani = matplotlib.animation.FuncAnimation(fig, animate, frames=len(t))

from IPython.display import HTML
help(ani.to_html5_video())
# Out:
# 2020-05-28 02:02:48,883 - matplotlib.animation - INFO - Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2020-05-28 02:02:48,886 - matplotlib.animation - INFO - MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 432x288 -pix_fmt rgba -r 5.0 -loglevel error -i pipe: -vcodec h264 -pix_fmt yuv420p -y /var/folders/yy/1mdqj2p5327cp4kq5d1f69200000gp/T/tmpmu_2g23u/temp.m4v
# 2020-05-28 02:02:49,022 - matplotlib.animation - WARNING - MovieWriter stderr:
# [h264_videotoolbox @ 0x7fad33809a00] Error: cannot create compression session: -12915
# [h264_videotoolbox @ 0x7fad33809a00] Try -allow_sw 1. The hardware encoder may be busy, or not supported.
# Error initializing output stream 0:0 -- Error while opening encoder for output stream #0:0 - maybe incorrect parameters such as bit_rate, rate, width or height
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     229         try:
# --> 230             yield self
#     231         finally:
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1151                             frame_number += 1
# -> 1152                     writer.grab_frame(**savefig_kwargs)
#    1153
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     384         self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 385                          dpi=self.dpi, **savefig_kwargs)
#     386
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2104                     bbox_inches_restore=_bbox_inches_restore,
# -> 2105                     **kwargs)
#    2106             finally:
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     449         with cbook.open_file_cm(filename_or_obj, "wb") as fh:
# --> 450             fh.write(renderer.buffer_rgba())
#     451
#
# BrokenPipeError: [Errno 32] Broken pipe
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-54-82310fb5b313> in <module>
# ----> 1 help(ani.to_html5_video())
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1330                                 bitrate=rcParams['animation.bitrate'],
#    1331                                 fps=1000. / self._interval)
# -> 1332                 self.save(str(path), writer=writer)
#    1333                 # Now open and base64 encode.
#    1334                 vid64 = base64.encodebytes(path.read_bytes())
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1150                             progress_callback(frame_number, total_frames)
#    1151                             frame_number += 1
# -> 1152                     writer.grab_frame(**savefig_kwargs)
#    1153
#    1154         # Reconnect signal for first draw if necessary
#
# ~/opt/anaconda3/envs/work/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      97                 value = type()
#      98             try:
# ---> 99                 self.gen.throw(type, value, traceback)
#     100             except StopIteration as exc:
#     101                 # Suppress StopIteration *unless* it's the same exception that
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in saving(self, fig, outfile, dpi, *args, **kwargs)
#     230             yield self
#     231         finally:
# --> 232             self.finish()
#     233
#     234
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in finish(self)
#     366     def finish(self):
#     367         '''Finish any processing for writing the movie.'''
# --> 368         self.cleanup()
#     369
#     370     def grab_frame(self, **savefig_kwargs):
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/matplotlib/animation.py in cleanup(self)
#     410         if self._proc.returncode:
#     411             raise subprocess.CalledProcessError(
# --> 412                 self._proc.returncode, self._proc.args, out, err)
#     413
#     414     @classmethod
#
# CalledProcessError: Command '['ffmpeg', '-f', 'rawvideo', '-vcodec', 'rawvideo', '-s', '432x288', '-pix_fmt', 'rgba', '-r', '5.0', '-loglevel', 'error', '-i', 'pipe:', '-vcodec', 'h264', '-pix_fmt', 'yuv420p', '-y', '/var/folders/yy/1mdqj2p5327cp4kq5d1f69200000gp/T/tmpmu_2g23u/temp.m4v']' returned non-zero exit status 1.

# %% [markdown]
# # Cost for each datapoint

# %%
# Set constraints and options Internationality(rho>1)
max_bound = 0.1 * np.ones(1)
min_bound = 0.001 * np.ones(1)
bounds = (min_bound,max_bound)
options = {'c1': 0.6, 'c2': 0.3, 'w': 0.9}
print(bounds)
# Out:
# (array([0.001]), array([0.1]))

# %%
costs = []
positions = []
K =[]
L=[]
for d in range(len(df))[:]:
    q.setparams(K=df['ICR'][d],L=df['NLIQ'][d],alpha=0.5)
    print(q.K,q.L)

    # Set-up optimizer
    optimizer = ps.single.GlobalBestPSO(n_particles=25, dimensions=1, options=options,bounds =bounds)
    cost,pos = optimizer.optimize(f, iters=100)
    # Plotting 2D and 3D cost history
    plot_cost_history(optimizer.cost_history)
    #plt.savefig('cost_history/2D/rho>1/cost_2D_'+df['Institute'][d]+'.png')
    
    m = Mesher(func=f,limits=[(-1,1), (-1,1)])
    # Adjust figure limits
    des = Designer(limits=[(-1,1), (-1,1), (-0.1,1)],label=['x-axis', 'y-axis', 'z-axis'])
    pos_history_3d = m.compute_history_3d(optimizer.pos_history) # preprocessing
    animation3d = plot_surface(pos_history=pos_history_3d,
                               mesher=m, designer=des,
                               mark=(0,0,0))   
    plt.savefig('cost_history/3D/0.1>rho>0.001/cost_3D_'+df['Institute'][d]+'.png')
    
    while pos[0] >max_bound[0] or pos[0]<min_bound[0]:
        optimizer = ps.single.GlobalBestPSO(n_particles=25, dimensions=1, options=options)
        cost,pos = optimizer.optimize(f, iters=100)
    print('Cost: %f\nPosition%f'%(cost,pos))
    # Plot the cost
    costs.append(cost)
    positions.append(pos[0])
# Out:
# 2020-05-28 02:51:28,138 - pyswarms.single.global_best - INFO - Optimize for 100 iters with {'c1': 0.6, 'c2': 0.3, 'w': 0.9}
#
#
# pyswarms.single.global_best:   0%|          |0/100
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:   0%|          |0/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
# 0.4474134631 0.5841363973
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  48%|████▊     |48/100, best_cost=0.511
#
# pyswarms.single.global_best:  93%|█████████▎|93/100, best_cost=0.511
#
# pyswarms.single.global_best:  93%|█████████▎|93/100, best_cost=0.511
#
# pyswarms.single.global_best:  93%|█████████▎|93/100, best_cost=0.511
#
# pyswarms.single.global_best:  93%|█████████▎|93/100, best_cost=0.511
#
# pyswarms.single.global_best:  93%|█████████▎|93/100, best_cost=0.511
#
# pyswarms.single.global_best:  93%|█████████▎|93/100, best_cost=0.511
#
# pyswarms.single.global_best:  93%|█████████▎|93/100, best_cost=0.511
#
# pyswarms.single.global_best: 100%|██████████|100/100, best_cost=0.511[A
# 2020-05-28 02:51:28,362 - pyswarms.single.global_best - INFO - Optimization finished | best cost: 0.5112291398410355, best pos: [0.00102136]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-101-7162a8f6e0f9> in <module>
#      21                                mesher=m, designer=d,
#      22                                mark=(0,0,0))
# ---> 23     plt.savefig('cost_history/3D/0.1>rho>0.001/cost_3D_'+df['Institute'][d]+'.png')
#      24
#      25     while pos[0] >max_bound[0] or pos[0]<min_bound[0]:
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/anaconda3/envs/work/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: Designer(figsize=(10, 8), title_fontsize='large', text_fontsize='medium', legend='Cost', label=['x-axis', 'y-axis', 'z-axis'], limits=[(-1, 1), (-1, 1), (-0.1, 1)], colormap=<matplotlib.colors.ListedColormap object at 0x1019b321d0>)

# %%
df['rho>1'] =positions
df['Internationality(rho>1'] = costs
df
# Out:
#                                    Institute  Articles  Articles w/ IC  \
# 0                            Yale University       139              38
# 1                           Brown University       113              32
# 2                          Boston University       135              37
# 3                    University of Groningen       108              31
# 4              Humboldt University of Berlin       113              29
# ..                                       ...       ...             ...
# 70                     University of Baghdad         8               2
# 71  Hanoi University of Science & Technology        15              10
# 72                 University of Puerto Rico        16              10
# 73                         Atilim University        31               6
# 74                      Universite de Bejaia        12               6
#
#     Total Citations  Parent Country Citations       ICR      NLIQ   Ranking  \
# 0              2698                      1122  0.447413  0.584136         8
# 1              2381                      1027  0.487884  0.568669        53
# 2              4170                      1740  0.490636  0.582734        61
# 3              1901                       308  0.490845  0.837980        73
# 4              2930                       697  0.590844  0.762116        74
# ..              ...                       ...       ...       ...       ...
# 70              341                        15  0.473333  0.956012  801-1000
# 71              160                         8  0.683347  0.950000  801-1000
# 72              668                       161  0.441312  0.758982  801-1000
# 73              416                        85  0.638889  0.795673  801-1000
# 74              121                         0  0.428241  1.000000  801-1000
#
#      1>rho>0  Internationality(1>rho>0  0.1>rho>0.001  \
# 0   0.000701                  0.511228       0.001026
# 1   0.000950                  0.526731       0.001050
# 2   0.000394                  0.534706       0.001051
# 3   0.000146                  0.641344       0.001078
# 4   0.000320                  0.671039       0.001015
# ..       ...                       ...            ...
# 70  0.000244                  0.672700       0.001035
# 71  0.000484                  0.805722       0.001025
# 72  0.000229                  0.578752       0.001062
# 73  0.000112                  0.712985       0.001055
# 74  0.000469                  0.654429       0.001042
#
#     Internationality(0.1>rho>0.001  0.99>rho>0.9  \
# 0                         0.511229      0.900103
# 1                         0.526731      0.900003
# 2                         0.534708      0.900019
# 3                         0.641366      0.900032
# 4                         0.671043      0.900028
# ..                             ...           ...
# 70                        0.672733      0.900008
# 71                        0.805728      0.900001
# 72                        0.578770      0.900066
# 73                        0.712989      0.900021
# 74                        0.654462      0.900052
#
#     Internationality(0.99>rho>0.9  0.9>rho>0.101  \
# 0                        0.515321       0.101045
# 1                        0.528122       0.101632
# 2                        0.536487       0.101004
# 3                        0.662116       0.101073
# 4                        0.675936       0.102083
# ..                            ...            ...
# 70                       0.710505       0.101663
# 71                       0.815580       0.101054
# 72                       0.598018       0.101280
# 73                       0.716852       0.101162
# 74                       0.708214       0.101021
#
#     Internationality(0.9>rho>0.101         rho>1  Internationality(rho>1
# 0                         0.511684  12807.607770                0.000000
# 1                         0.526887  96662.076040                0.000000
# 2                         0.534906  32685.899073                0.000000
# 3                         0.643663  90607.933466                0.000000
# 4                         0.671593  50440.424860                0.000000
# ..                             ...           ...                     ...
# 70                        0.676927  82873.805043                0.000000
# 71                        0.806822  14594.578722                0.000000
# 72                        0.580905  35698.394658                0.000000
# 73                        0.713419  66718.161750                0.000000
# 74                        0.660370      8.780424                0.924155
#
# [75 rows x 18 columns]

# %%
df.to_csv('result/result_alpha_0.5.csv',index=False)

# %%
df[df['Institute'].isin(['Simon Fraser University','Indian Institute of Technology (IIT) - Kharagpur'])]
# Out:
#                                            Institute  Articles  \
# 22  Indian Institute of Technology (IIT) - Kharagpur        32
# 32                           Simon Fraser University        66
#
#     Articles w/ IC  Total Citations  Parent Country Citations       ICR  \
# 22               8              262                        49  0.463333
# 32              15              593                        97  0.462083
#
#         NLIQ  Ranking      cost       rho  Internationality(1>rho>0)  \
# 22  0.812977      0.0  0.768536  0.000730                   0.768531
# 32  0.836425     60.0  0.788240  0.000277                   0.788256
#
#     Internationality(0.1>rho>0.001)  Internationality(0.99>rho>0.9)  \
# 22                         0.768540                        0.777186
# 32                         0.788249                        0.798060
#
#     Internationality(0.9>rho>0.101)  Internationality(rho>1)  \
# 22                         0.769618                      0.0
# 32                         0.789484                      0.0
#
#     Internationality(1rho>0)
# 22                  0.768536
# 32                  0.788240

# %%
temp =df
temp = temp.sort_values(by=['1>rho>0'])
#print(temp)
x = temp['1>rho>0']
y = temp['Internationality(1>rho>0']

fig=plt.figure()
#ax=fig.add_axes([0,0,1,1])
plt.scatter(x, y, color='r')

plt.xlabel('rho')
plt.ylabel("Q")
plt.title('Q Vs rho')
plt.savefig('qVSrho.png')

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = temp['ICR']
#X = np.arange(-5, 5, 1)
Y = temp['NLIQ']
#Y = np.arange(-5, 5, 1)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)
print()
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# # Graphs for different ranges of rho

# %%
r = (0.00001,1)

# %%
i = r[0]
rho = []
inter = []
Q1 =[]
Q1_new=[]
k=df['ICR'][4]
l=df['NLIQ'][4]
q.setparams(K=k,L=l)
while i<r[1]:
    inter.append(q.Q(i))
    Q1.append(q.Q1(i))
    Q1_new.append(q.Q1_new(i))
    rho.append(i)
    i+=.001

# %%
x = rho
y = inter

fig=plt.figure()
#ax=fig.add_axes([0,0,1,1])
plt.scatter(x, y, color='c',s=1,label='Q')
plt.scatter(x, Q1, color='r',s=1,label='Q\'-Taylor series')
#plt.scatter(x, Q1_new, color='g',s=1,label='Q\'-Chain Rule')
plt.xlabel('rho')
plt.ylabel("Q\'")
plt.legend()
plt.title('rho='+str(r[0])+'-'+str(r[1]) +' K='+ str(round(k,4))+' L='+ str(round(l,4)))
plt.savefig('graphs/'+str(round(k,2))+'-'+str(round(l,2))+'.png')

# %%
temp
# Out:
#                                             Institute  Articles  \
# 9                                   Auburn University         7
# 35                     University of British Columbia        85
# 49                                  Yonsei University        41
# 10                     Australian National University        56
# 23      Indian Institute of Technology (IIT) - Madras        37
# 20      Indian Institute of Technology (IIT) - Bombay        11
# 36                            University of Edinburgh        83
# 12          Benemerita Universidad Autonoma de Puebla        15
# 6                                   Ankara University         3
# 11                  Babes Bolyai University from Cluj         7
# 40                               University of Ottawa        39
# 34     State University of New York (SUNY) Binghamton        13
# 17           Ecole Polytechnique Federale de Lausanne       268
# 44                  University of Southern Queensland         2
# 22   Indian Institute of Technology (IIT) - Kharagpur        32
# 18     Indian Institute of Science (IISC) - Bangalore        39
# 8                            Arizona State University        80
# 37                               University of Guelph        45
# 3                               Alexandria University         5
# 16                                 Cornell University       121
# 38                             University of Michigan       218
# 46                              University of Toronto       200
# 30                                     PES University         2
# 7                            Aoyama Gakuin University        15
# 32                            Simon Fraser University        66
# 19  Indian Institute of Technology (IIT BHU) - Var...         9
# 0              AGH University of Science & Technology        29
# 47                             University of Waterloo        91
# 4                                    Amity University         3
# 31                             RWTH Aachen University        59
# 43                  University of Southern California       173
# 1                                 Al Azhar University         5
# 13  Birla Institute of Technology and Science Pila...         9
# 42                              University of Salford        24
# 28         National Institute of Technology Karnataka         2
# 33                                  Sogang University        19
# 48                                    Yale University        84
# 15                                Columbia University        72
# 27                                  McGill University       103
# 45                                University of Tokyo       390
# 2        Al-Imam Muhammad Ibn Saud Islamic University         2
# 14                          Colorado State University        25
# 26                                 Manipal University         5
# 25                           Johns Hopkins University       130
# 21       Indian Institute of Technology (IIT) - Delhi        25
# 29                    North Carolina State University        31
# 41                         University of Pennsylvania       222
# 39                             University of Montreal        56
# 5                          Amrita Vishwa Vidyapeetham         4
# 24     Indian Institute of Technology (IIT) - Roorkee        22
#
#     Articles w/ IC  Total Citations  Parent Country Citations       ICR  \
# 9                1               52                         7  1.000000
# 35              26             1642                       147  0.375978
# 49               5              250                        66  0.243333
# 10              20             1901                       137  0.492913
# 23               7              329                        53  0.557143
# 20               0              230                        20  0.010000
# 36              34              860                        51  0.280757
# 12               2               45                        14  0.270833
# 6                2               12                         2  0.284375
# 11               2               28                         5  0.322917
# 40               8              291                        53  0.677500
# 34               2              120                        28  0.500000
# 17              83             5320                       475  0.315530
# 44               1               11                         1  0.750000
# 22               8              262                        49  0.463333
# 18               7              449                        68  0.857143
# 8               19              558                       189  0.387015
# 37              23              232                        33  0.298200
# 3                2               46                         3  0.583333
# 16              16             3530                      1378  0.423913
# 38              35             3916                      1290  0.368524
# 46              44             2002                       301  0.441020
# 30               0                9                         2  0.010000
# 7                0               29                         6  0.010000
# 32              15              593                        97  0.462083
# 19               1               75                        35  0.666667
# 16                         0.588229                 0.000000
# 38                         0.632638                 0.000000
# 46                         0.797257                 0.000000
# 30                         0.543382                 0.000000
# 7                          0.553546                 0.000000
# 32                         0.789484                 0.000000
# 19                         0.545493                 0.000000
# 0                          0.379797                 0.000000
# 47                         0.836550                 0.000000
# 4                          0.470626                 0.000000
# 31                         0.731980                 0.000000
# 43                         0.656957                 0.000000
# 1                          0.759295                 0.000000
# 13                         0.851466                 0.000000
# 42                         0.790278                 0.000000
# 28                         0.282171                 0.000000
# 33                         0.729402                 0.000000
# 48                         0.665113                 0.000000
# 15                         0.639609                 0.000000
# 27                         0.830832                 0.000000
# 45                         0.722296                 0.000000
# 2                          0.501903                 0.000000
# 14                         0.735623                 0.000000
# 26                         0.602857                 0.000000
# 25                         0.583782                 0.000000
# 21                         0.752653                 0.000000
# 29                         0.586831                 0.000000
# 41                         0.596932                 0.000000
# 39                         0.725970                 0.000000
# 5                          0.623008                 0.000000
# 24                         0.672410                 0.000000

# %% [markdown]
# # IGNORE

# %%
max_bound = 1.0 * np.ones(1)
min_bound = 0*max_bound
bounds = (min_bound, max_bound)

my_topology = Star() # The Topology Class
my_options = {'c1': 0.6, 'c2': 0.3, 'w': 0.9} # arbitrarily set
my_swarm = P.create_swarm(n_particles=100, dimensions=1, options=my_options,bounds=bounds) # The Swarm Class

print('The following are the attributes of our swarm: {}'.format(my_swarm.__dict__.keys()))
# Out:
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])

# %%
iterations = 100 # Set 100 iterations
costs = []
positions = []
K =[]
L=[]
for d in range(len(df)):
    q.setparams(K=df['ICR'][d],L=df['NLIQ'][d])
    print(q.K,q.L)
    
    my_swarm = P.create_swarm(n_particles=5, dimensions=1, options=my_options,bounds=bounds) # The Swarm Class
    print('The following are the attributes of our swarm: {}'.format(my_swarm.__dict__.keys()))
    for i in range(iterations):
        # Part 1: Update personal best
        my_swarm.current_cost = f(my_swarm.position) # Compute current cost
        #print(my_swarm.current_cost)
        my_swarm.pbest_cost = f(my_swarm.pbest_pos)  # Compute personal best pos
        my_swarm.pbest_pos, my_swarm.pbest_cost = P.compute_pbest(my_swarm) # Update and store

        # Part 2: Update global best
        # Note that gbest computation is dependent on your topology
        if np.min(my_swarm.pbest_cost) < my_swarm.best_cost:
            my_swarm.best_pos, my_swarm.best_cost = my_topology.compute_gbest(my_swarm)

        # Let's print our output
        if i%20==0:
            print('Iteration: {} | my_swarm.best_cost: {:.4f}'.format(i+1, my_swarm.best_cost))

        # Part 3: Update position and velocity matrices
        # Note that position and velocity updates are dependent on your topology
        my_swarm.velocity = my_topology.compute_velocity(my_swarm)
        my_swarm.position = my_topology.compute_position(my_swarm)
        
    print('The best cost found by our swarm is: {:.4f}'.format(my_swarm.best_cost))
    costs.append(my_swarm.best_cost)
    print('The best position found by our swarm is: {}'.format(my_swarm.best_pos))
    positions.append(my_swarm.best_pos[0])
# Out:
# 0.3061728395 0.38888888899999996
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1342
# Iteration: 21 | my_swarm.best_cost: 0.0062
# Iteration: 41 | my_swarm.best_cost: 0.0001
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-13.73086102]
# 0.6666666667 0.77027027
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0271
# Iteration: 21 | my_swarm.best_cost: 0.1839
# Iteration: 41 | my_swarm.best_cost: 0.0425
# Iteration: 61 | my_swarm.best_cost: 0.0209
# Iteration: 81 | my_swarm.best_cost: 0.0128
# The best cost found by our swarm is: 0.0087
# The best position found by our swarm is: [-15.49429424]
# 0.0 0.7142857140000001
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.48307554]
# 0.5833333333 0.9347826090000001
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0081
# Iteration: 21 | my_swarm.best_cost: 0.0104
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-36.12551829]
# 0.0 0.666666667
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.66497957]
# 0.0 0.9
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.58859131]
# 0.284375 0.833333333
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0007
# Iteration: 21 | my_swarm.best_cost: 0.0002
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-30.77792972]
# 0.0 0.793103448
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.59057852]
# 0.3870150286 0.661290323
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1835
# Iteration: 21 | my_swarm.best_cost: 0.0001
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-29.35160558]
# 1.0 0.865384615
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0028
# Iteration: 21 | my_swarm.best_cost: 0.3284
# Iteration: 41 | my_swarm.best_cost: 0.1274
# Iteration: 61 | my_swarm.best_cost: 0.0675
# Iteration: 81 | my_swarm.best_cost: 0.0442
# The best cost found by our swarm is: 0.0349
# The best position found by our swarm is: [-23.40097675]
# 0.4929128597 0.927932667
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0250
# Iteration: 21 | my_swarm.best_cost: 0.0107
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-28.00860574]
# 0.3229166667 0.8214285709999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0612
# Iteration: 21 | my_swarm.best_cost: 0.0092
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-19.44201579]
# 0.2708333333 0.688888889
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0713
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-24.36029306]
# 0.3333333333 0.94
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1008
# Iteration: 21 | my_swarm.best_cost: 0.0001
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-50.70485774]
# 0.4088541667 0.78358209
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0093
# Iteration: 21 | my_swarm.best_cost: 0.0030
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-24.24793082]
# 0.3941666667 0.673983215
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1413
# Iteration: 21 | my_swarm.best_cost: 0.0004
# Iteration: 41 | my_swarm.best_cost: 0.0000
# /Users/poulamisarkar/opt/anaconda3/envs/work/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: divide by zero encountered in double_scalars
#   if __name__ == '__main__':
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-64.16211562]
# 0.0 0.609631728
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.31044877]
# 0.0 0.9107142859999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.02652943]
# 0.8571428570999999 0.848552339
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0056
# Iteration: 21 | my_swarm.best_cost: 0.2686
# Iteration: 41 | my_swarm.best_cost: 0.0578
# Iteration: 61 | my_swarm.best_cost: 0.0296
# Iteration: 81 | my_swarm.best_cost: 0.0227
# The best cost found by our swarm is: 0.0199
# The best position found by our swarm is: [-23.98461672]
# 0.6666666667 0.533333333
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0808
# Iteration: 21 | my_swarm.best_cost: 0.0015
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-33.67611494]
# 0.0 0.913043478
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.50812622]
# 0.30305555559999997 0.828571429
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0004
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-29.00183792]
# 0.4633333333 0.812977099
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0259
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-56.13451306]
# 0.5571428571 0.838905775
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0057
# Iteration: 21 | my_swarm.best_cost: 0.0144
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-52.46759706]
# 0.4133333333 0.708737864
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1195
# Iteration: 21 | my_swarm.best_cost: 0.0009
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-31.84646588]
# 0.0 0.611092878
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.42701992]
# 0.5 0.615384615
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1001
# Iteration: 21 | my_swarm.best_cost: 0.0017
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-50.28326255]
# 0.0 0.8684210529999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.86412548]
# 0.0 0.384615385
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.42122252]
# 0.3333333333 0.623655914
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1066
# Iteration: 21 | my_swarm.best_cost: 0.0005
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-32.08268605]
# 0.0 0.7777777779999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.41200206]
# 0.3149739051 0.8004032259999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1867
# Iteration: 21 | my_swarm.best_cost: 0.0031
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-32.63500599]
# 0.4620833333 0.8364249579999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1103
# Iteration: 21 | my_swarm.best_cost: 0.0186
# Iteration: 41 | my_swarm.best_cost: 0.0001
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-27.55261242]
# 0.3388518519 0.791411043
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0025
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-52.97848446]
# 0.5 0.7666666670000001
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0071
# Iteration: 21 | my_swarm.best_cost: 0.0185
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-36.13356306]
# 0.37597756409999994 0.91047503
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.2036
# Iteration: 21 | my_swarm.best_cost: 0.0001
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-49.08890692]
# 0.28075664699999997 0.940697674
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.2243
# Iteration: 21 | my_swarm.best_cost: 0.0018
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-14.42792794]
# 0.29820048309999997 0.8577586209999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0172
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-47.64007001]
# 0.0 0.670582227
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.73171425]
# 0.1831309524 0.836575875
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.2073
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-67.02499161]
# 0.6775 0.817869416
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1049
# Iteration: 21 | my_swarm.best_cost: 0.2384
# Iteration: 41 | my_swarm.best_cost: 0.0241
# Iteration: 61 | my_swarm.best_cost: 0.0054
# Iteration: 81 | my_swarm.best_cost: 0.0029
# The best cost found by our swarm is: 0.0020
# The best position found by our swarm is: [-20.83443689]
# 0.0 0.633903652
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.76046776]
# 0.3088253158 0.872596154
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0337
# Iteration: 21 | my_swarm.best_cost: 0.0001
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-28.9712623]
# 0.0 0.688867124
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.65393764]
# 0.75 0.9090909090000001
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0123
# Iteration: 21 | my_swarm.best_cost: 0.2054
# Iteration: 41 | my_swarm.best_cost: 0.0214
# Iteration: 61 | my_swarm.best_cost: 0.0048
# Iteration: 81 | my_swarm.best_cost: 0.0023
# The best cost found by our swarm is: 0.0017
# The best position found by our swarm is: [-28.06314421]
# 0.0 0.756448989
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.38464782]
# 0.0 0.84965035
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 0.0000
# Iteration: 21 | my_swarm.best_cost: 0.0000
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [0.05435304]
# 0.5167769061 0.8812893079999999
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0390
# Iteration: 21 | my_swarm.best_cost: 0.0167
# Iteration: 41 | my_swarm.best_cost: 0.0002
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-22.43483916]
# 0.521301468 0.683111954
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.0441
# Iteration: 21 | my_swarm.best_cost: 0.0117
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-35.55553497]
# 0.24333333329999998 0.736
# The following are the attributes of our swarm: dict_keys(['position', 'velocity', 'n_particles', 'dimensions', 'options', 'pbest_pos', 'best_pos', 'pbest_cost', 'best_cost', 'current_cost'])
# Iteration: 1 | my_swarm.best_cost: 1.1258
# Iteration: 21 | my_swarm.best_cost: 0.0001
# Iteration: 41 | my_swarm.best_cost: 0.0000
# Iteration: 61 | my_swarm.best_cost: 0.0000
# Iteration: 81 | my_swarm.best_cost: 0.0000
# The best cost found by our swarm is: 0.0000
# The best position found by our swarm is: [-44.61183181]

# %%
df = pd.read_csv("result/combined_v1.csv")

# %%
df
# Out:
#                                             Institute  Articles  \
# 0              AGH University of Science & Technology        29
# 1                                 Al Azhar University         5
# 2        Al-Imam Muhammad Ibn Saud Islamic University         2
# 3                               Alexandria University         5
# 4                                    Amity University         3
# 5                          Amrita Vishwa Vidyapeetham         4
# 6                                   Ankara University         3
# 7                            Aoyama Gakuin University        15
# 8                            Arizona State University        80
# 9                                   Auburn University         7
# 10                     Australian National University        56
# 11                  Babes Bolyai University from Cluj         7
# 12          Benemerita Universidad Autonoma de Puebla        15
# 13  Birla Institute of Technology and Science Pila...         9
# 14                          Colorado State University        25
# 15                                Columbia University        72
# 16                                 Cornell University       121
# 17           Ecole Polytechnique Federale de Lausanne       268
# 18     Indian Institute of Science (IISC) - Bangalore        39
# 19  Indian Institute of Technology (IIT BHU) - Var...         9
# 20      Indian Institute of Technology (IIT) - Bombay        11
# 21       Indian Institute of Technology (IIT) - Delhi        25
# 22   Indian Institute of Technology (IIT) - Kharagpur        32
# 23      Indian Institute of Technology (IIT) - Madras        37
# 24     Indian Institute of Technology (IIT) - Roorkee        22
# 25                           Johns Hopkins University       130
# 26                                 Manipal University         5
# 27                                  McGill University       103
# 28         National Institute of Technology Karnataka         2
# 29                    North Carolina State University        31
# 30                                     PES University         2
# 31                             RWTH Aachen University        59
# 32                            Simon Fraser University        66
# 33                                  Sogang University        19
# 34     State University of New York (SUNY) Binghamton        13
# 35                     University of British Columbia        85
# 36                            University of Edinburgh        83
# 37                               University of Guelph        45
# 38                             University of Michigan       218
# 39                             University of Montreal        56
# 40                               University of Ottawa        39
# 41                         University of Pennsylvania       222
# 42                              University of Salford        24
# 43                  University of Southern California       173
# 44                  University of Southern Queensland         2
# 45                                University of Tokyo       390
# 46                              University of Toronto       200
# 47                             University of Waterloo        91
# 48                                    Yale University        84
# 49                                  Yonsei University        41
#
#     Articles w/ IC  Total Citations  Parent Country Citations       ICR  \
# 0              3.0               54                        33  0.306173
# 1              1.0               74                        17  0.666667
# 2              0.0                7                         2  0.010000
# 3              2.0               46                         3  0.583333
# 4              0.0                3                         1  0.010000
# 5              0.0               10                         1  0.010000
# 6              2.0               12                         2  0.284375
# 7              0.0               29                         6  0.010000
# 8             19.0              558                       189  0.387015
# 9              1.0               52                         7  1.000000
# 10            20.0             1901                       137  0.492913
# 11             2.0               28                         5  0.322917
# 12             2.0               45                        14  0.270833
# 13             1.0               50                         3  0.333333
# 14             4.0              134                        29  0.408854
# 15            13.0             1549                       505  0.394167
# 16             0.0             3530                      1378  0.010000
# 17             0.0             5320                       475  0.010000
# 18             7.0              449                        68  0.857143
# 19             1.0               75                        35  0.666667
# 20             0.0              230                        20  0.010000
# 21             6.0              210                        36  0.303056
# 22             8.0              262                        49  0.463333
# 23             7.0              329                        53  0.557143
# 24             3.0              103                        30  0.413333
# 25             0.0             3047                      1185  0.010000
# 26             2.0               39                        15  0.500000
# 27             0.0             1634                       215  0.010000
# 28             0.0               13                         8  0.010000
# 29             2.0              279                       105  0.333333
# 30             0.0                9                         2  0.010000
# 31            17.0              496                        99  0.314974
# 32            15.0              593                        97  0.462083
# 33            10.0              163                        34  0.338852
# 34             2.0              120                        28  0.500000
# 35            26.0             1642                       147  0.375978
# 36            34.0              860                        51  0.280757
# 37            23.0              232                        33  0.298200
# 38             0.0             3916                      1290  0.010000
# 39            10.0              771                       126  0.183131
# 40             8.0              291                        53  0.677500
# 41             0.0             8241                      3017  0.010000
# 42             7.0              416                        53  0.308825
# 7                          0.512665                         0.553580
# 8                          0.626803                         0.627603
# 9                          0.877988                         0.878071
# 10                         0.871063                         0.872608
# 11                         0.748238                         0.751107
# 12                         0.627513                         0.629917
# 13                         0.847470                         0.851520
# 14                         0.734246                         0.735623
# 15                         0.638790                         0.639610
# 16                         0.404488                         0.433104
# 17                         0.580553                         0.629703
# 18                         0.849408                         0.849408
# 19                         0.545369                         0.545494
# 20                         0.581892                         0.631177
# 21                         0.749325                         0.752665
# 22                         0.768541                         0.769628
# 23                         0.805271                         0.805871
# 24                         0.671542                         0.672412
# 25                         0.405355                         0.433948
# 26                         0.602740                         0.602856
# 27                         0.556263                         0.602336
# 28                         0.267183                         0.282113
# 29                         0.585796                         0.586815
# 30                         0.503664                         0.543396
# 31                         0.729160                         0.731966
# 32                         0.788249                         0.789481
# 33                         0.727074                         0.729380
# 34                         0.734593                         0.735195
# 35                         0.833441                         0.836323
# 36                         0.833625                         0.838957
# 37                         0.771795                         0.775574
# 38                         0.440719                         0.473208
# 39                         0.718748                         0.725962
# 40                         0.802615                         0.802743
# 41                         0.418959                         0.449088
# 42                         0.786547                         0.790283
# 43                         0.451520                         0.485182
# 44                         0.891771                         0.891919
# 45                         0.491221                         0.529514
# 46                         0.545459                         0.590221
# 47                         0.835493                         0.836550
# 48                         0.664895                         0.665117
# 49                         0.658923                         0.662470
#
#     Internationality(0.99>rho>0.9)  Internationality(rho>1)
# 0                         0.380531                 0.000000
# 1                         0.759844                 0.000000
# 2                         0.637059                 0.000000
# 3                         0.898932                 0.000000
# 4                         0.594689                 0.000000
# 5                         0.802306                 0.000000
# 6                         0.776128                 0.000000
# 7                         0.707194                 0.000000
# 8                         0.633242                 0.000000
# 9                         0.878757                 0.998103
# 10                        0.883283                 0.000000
# 11                        0.769717                 0.000000
# 12                        0.645523                 0.000000
# 13                        0.876860                 0.000000
# 14                        0.745095                 0.000000
# 15                        0.645368                 0.000000
# 16                        0.543940                 0.000000
# 17                        0.811831                 0.000000
# 18                        0.849411                 0.000000
# 19                        0.546530                 0.000000
# 20                        0.813903                 0.000000
# 21                        0.773929                 0.000000
# 22                        0.777186                 0.000000
# 23                        0.810235                 0.000000
# 24                        0.678525                 0.000000
# 25                        0.545241                 0.000000
# 26                        0.603741                 0.000000
# 27                        0.774205                 0.000000
# 28                        0.343712                 0.000000
# 29                        0.593865                 0.000000
# 30                        0.693562                 0.000000
# 31                        0.750050                 0.000000
# 32                        0.798061                 0.000000
# 33                        0.744601                 0.000000
# 34                        0.739512                 0.000000
# 35                        0.855122                 0.000000
# 36                        0.871641                 0.000000
# 37                        0.799481                 0.000000
# 38                        0.598180                 0.000000
# 39                        0.767603                 0.000000
# 40                        0.803716                 0.000000
# 41                        0.565538                 0.000000
# 42                        0.813914                 0.000000
# 43                        0.614442                 0.000000
# 44                        0.893047                 0.000000
# 45                        0.674576                 0.000000
# 46                        0.757505                 0.000000
# 47                        0.844017                 0.000000
# 48                        0.666740                 0.000000
# 49                        0.684609                 0.000000

# %%
len(positions)
# Out:
# 50

# %%
np.nan
# Out:
# nan
